# %% [markdown]
# <a href="https://colab.research.google.com/github/Katetuna/innopolis/blob/main/%D0%97%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_%D0%BF%D0%BE_%D0%B2%D0%B8%D0%B7%D1%83%D0%B0%D0%BB%D0%B8%D0%B7%D0%B0%D1%86%D0%B8%D0%B8_(pandas).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Файл df3.csv находится в архиве с заданием

# %%
# Запустите эту ячейку
import pandas as pd
# %matplotlib inline

df3 = pd.read_csv('df3.csv')
print(len(df3))
print(df3.head())
# Out:
# 500
#        weekday  produced  defective
# 0     1.Monday        73          7
# 1    2.Tuesday        75         10
# 2  3.Wednesday        86          7
# 3   4.Thursday        64          7
# 4     5.Friday        70          6

# %% [markdown]
# Эти данные представляют собой заводские производственные показатели и сообщенное количество дефектов в определенные дни недели.

# %% [markdown]
# ### 1. Воссоздайте этот график разброса «произведенных» и «дефектных»  деталей. Обратите внимание на цвет и размер точек. Также обратите внимание на размер картинки. Сможете ли растянуть его аналогичным образом?

# %%
# ВАШ КОД
df3.plot.scatter(x="produced" , y = 'defective',  c="red", figsize=(12,3))

# %%
# ОЖИДАЕМЫЙ РЕЗУЛЬТАТ

# %% [markdown]
# ### 2. Создайте гистограмму для колонки 'produced'

# %%
# ВАШ КОД
df3['produced'].plot.hist()

# %%
# ОЖИДАЕМЫЙ РЕЗУЛЬТАТ

# %% [markdown]
# ### 3. Перерисуйте гистограмму как на рисунке ниже

# %%
# ВАШ КОД
df3['produced'].plot.hist(edgecolor='black', ).autoscale(enable = True, axis="x", tight=True)

# %%
# ОЖИДАЕМЫЙ РЕЗУЛЬТАТ

# %% [markdown]
# ### 4. Создайте boxplot для 'produced' в каждый из дней недели 'weekday' (используйте группировку)

# %%
# ВАШ КОД
df3[['produced','weekday']].boxplot(by='weekday', grid = False)

# %%
# ОЖИДАЕМЫЙ РЕЗУЛЬТАТ

# %% [markdown]
# ### 5.Создайте KDE (ядерная оценка плотности) для колонки 'defective'

# %%
# ВАШ КОД
df3['defective'].plot.kde()

# %%
# ОЖИДАЕМЫЙ РЕЗУЛЬТАТ

# %% [markdown]
# ### 6. Видоизмените график KDE, как на рисунке ниже

# %%
# ВАШ КОД
df3['defective'].plot.kde(linestyle = '--', linewidth=5)

# %%
# ОЖИДАЕМЫЙ РЕЗУЛЬТАТ

# %% [markdown]
# ### 7. Для первых 30 строк постройте графики областей «произведенных» и «дефектных» деалей. (используйте .loc)

# %%
# ВАШ КОД
df3.loc[0:29].plot.area(alpha=0.4,stacked=False)

# %%
# ОЖИДАЕМЫЙ РЕЗУЛЬТАТ

# %% [markdown]
# Поменяйте расположение легенды на графике (как показано ниже)

# %%
# ВАШ КОД
df3.loc[0:29].plot.area(alpha=0.4,stacked=False).legend(bbox_to_anchor=(1.3, 0.6))

# %%
# ОЖИДАЕМЫЙ РЕЗУЛЬТАТ
